# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
data = pd.DataFrame({'Months': ['jan','feb','mar','apr','may','jun','jul','agu','sep','oct','nov','dec'],
                    'Sales': [400,500,700,450,620,400,500,700,450,620,456,625],
                     'Profit': [220,78,392,35,62,220,78,392,235,162,135,285],
                    })

# %%
plt.figure(figsize=(16,6))
sns.lineplot(data)
# Out:
# <Axes: >

# %%
### Importing Seaborn

#   import seaborn as sns
#   import matplotlib.pyplot as plt

# %%
### Loading Example Datasets
#   Seaborn comes with a few example datasets in the `sns.load_dataset()` function.

#   tips = sns.load_dataset('tips')

# %%
### Basic Plot Types

#### 1. **Scatter Plot**

#   sns.scatterplot(data=tips, x='total_bill', y='tip')
#   plt.show()

# %%
#### 2. **Line Plot**

#   sns.lineplot(data=tips, x='total_bill', y='tip')
#   plt.show()

# %%
#### 3. **Bar Plot**

#   sns.barplot(data=tips, x='day', y='total_bill')
#   plt.show()

# %%
#### 4. **Histogram**

#   sns.histplot(data=tips, x='total_bill', bins=10)
#   plt.show()

# %%
#### 5. **Box Plot**

#   sns.boxplot(data=tips, x='day', y='total_bill')
#   plt.show()

# %%
#### 6. **Violin Plot**

#   sns.violinplot(data=tips, x='day', y='total_bill')
#   plt.show()

# %%
#### 7. **Pair Plot**

#   sns.pairplot(tips)
#   plt.show()

# %%
#### 8. **Heatmap**

#   corr = tips.corr()
#   sns.heatmap(corr, annot=True, cmap='coolwarm')
#   plt.show()

# %%
### Importing Seaborn

#   import seaborn as sns
#   import matplotlib.pyplot as plt


### Loading Example Datasets
#   Seaborn comes with a few example datasets in the `sns.load_dataset()` function.

#   tips = sns.load_dataset('tips')

# %%
### Basic Plot Types

#### 1. **Scatter Plot**

#   sns.scatterplot(data=tips, x='total_bill', y='tip')
#   plt.show()


#### 2. **Line Plot**

#   sns.lineplot(data=tips, x='total_bill', y='tip')
#   plt.show()


#### 3. **Bar Plot**

#   sns.barplot(data=tips, x='day', y='total_bill')
#   plt.show()


#### 4. **Histogram**

#   #   sns.histplot(data=tips, x='total_bill', bins=10)
#   #   plt.show()


#### 5. **Box Plot**

#   #   sns.boxplot(data=tips, x='day', y='total_bill')
#   #   plt.show()


#### 6. **Violin Plot**

#   #   sns.violinplot(data=tips, x='day', y='total_bill')
#   #   plt.show()


#### 7. **Pair Plot**

#   sns.pairplot(tips)
#   #   plt.show()


#### 8. **Heatmap**

#   #   corr = tips.corr()
#   #   sns.heatmap(corr, annot=True, cmap='coolwarm')
#   #   plt.show()

# %%
### Customizing Plots

#### 1. **Adding Titles and Labels**

#   sns.scatterplot(data=tips, x='total_bill', y='tip')
#   plt.title('Scatter plot of Total Bill vs Tip')
#   plt.xlabel('Total Bill')
#   plt.ylabel('Tip')
#   plt.show()


#### 2. **Setting Styles**

#   sns.set_style('whitegrid')
#   sns.scatterplot(data=tips, x='total_bill', y='tip')
#   plt.show()


#### 3. **Color Palettes**

#   sns.set_palette('pastel')
#   sns.barplot(data=tips, x='day', y='total_bill')
#   plt.show()

# %%
### Advanced Plot Types

#### 1. **FacetGrid**

#   g = sns.FacetGrid(tips, col='day', col_wrap=2)
#   g.map(sns.scatterplot, 'total_bill', 'tip')
#   plt.show()


#### 2. **Joint Plot**

#   sns.jointplot(data=tips, x='total_bill', y='tip', kind='reg')
#   plt.show()
#   

#### 3. **PairGrid**

#   g = sns.PairGrid(tips)
#   g.map_upper(sns.scatterplot)
#   g.map_lower(sns.kdeplot)
#   g.map_diag(sns.histplot)
#   plt.show()

# %%
### Importing Seaborn

#   import seaborn as sns
#   import matplotlib.pyplot as plt


### Loading Example Datasets
#   Seaborn comes with a few example datasets in the `sns.load_dataset()` function.

#   tips = sns.load_dataset('tips')


### Basic Plot Types

#### 1. **Scatter Plot**

#   sns.scatterplot(data=tips, x='total_bill', y='tip')
#   plt.show()



#### 2. **Line Plot**

#   sns.lineplot(data=tips, x='total_bill', y='tip')
#   plt.show()


#### 3. **Bar Plot**

#   sns.barplot(data=tips, x='day', y='total_bill')
#   plt.show()

#### 4. **Histogram**

#   sns.histplot(data=tips, x='total_bill', bins=10)
#   plt.show()


#### 5. **Box Plot**

#   sns.boxplot(data=tips, x='day', y='total_bill')
#   plt.show()


#### 6. **Violin Plot**

#   sns.violinplot(data=tips, x='day', y='total_bill')
#   plt.show()


#### 7. **Pair Plot**

#   sns.pairplot(tips)
#   #   plt.show()


#### 8. **Heatmap**

#   #   corr = tips.corr()
#   #   sns.heatmap(corr, annot=True, cmap='coolwarm')
#   #   plt.show()


### Customizing Plots

#### 1. **Adding Titles and Labels**

#   #   sns.scatterplot(data=tips, x='total_bill', y='tip')
#   #   plt.title('Scatter plot of Total Bill vs Tip')
#   #   plt.xlabel('Total Bill')
#   #   plt.ylabel('Tip')
#   #   plt.show()


#### 2. **Setting Styles**

#   #   sns.set_style('whitegrid')
#   #   sns.scatterplot(data=tips, x='total_bill', y='tip')
#   #   plt.show()


#### 3. **Color Palettes**

#   sns.set_palette('pastel')
#   sns.barplot(data=tips, x='day', y='total_bill')
#   plt.show()


### Advanced Plot Types

#### 1. **FacetGrid**

#   g = sns.FacetGrid(tips, col='day', col_wrap=2)
#   g.map(sns.scatterplot, 'total_bill', 'tip')
#   plt.show()


#### 2. **Joint Plot**

#   sns.jointplot(data=tips, x='total_bill', y='tip', kind='reg')
#   plt.show()


#### 3. **PairGrid**

#   g = sns.PairGrid(tips)
#   g.map_upper(sns.scatterplot)
#   g.map_lower(sns.kdeplot)
#   g.map_diag(sns.histplot)
#   plt.show()
